# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
# Make sure we're in the right directory
if os.path.basename(os.getcwd()) == "notebooks":
    os.chdir("..")

from os.path import join
from pathlib import Path
from typing import Optional, Union, List, Sequence
import pytorch_lightning as pl
import numpy as np
import xarray as xr
import torch
import torch.nn as nn
from torch import Tensor
from matplotlib import pyplot as plt
from src.utilities.wandb_api import reload_checkpoint_from_wandb
from src.interface import get_predictions

# %%
data_dir = Path("/global/cfs/cdirs/m3504/oisstv2-daily")
wandb_id = '3kkx899f'

# %%
def reload_and_plot_preds(wandb_id: str, ar_steps=0):
    reloaded = reload_checkpoint_from_wandb(wandb_id, override_key_value=[f'datamodule.data_dir={str(data_dir)}'])
    model = reloaded['model']
    datamodule = reloaded['datamodule']
    datamodule.update_predict_data(predict_slice=slice('2020-12-01', '2020-12-31'), boxes=[88]) # slice('2020-01-01', '2021-12-31')
    datamodule.setup('predict')
    dataloader = datamodule.predict_dataloader()
    results = get_predictions(model, dataloader, ar_steps)
    return results

# %%
results = reload_and_plot_preds(wandb_id, ar_steps=8)
results_mlp = reload_and_plot_preds('8319ujtg', ar_steps=8)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /usr/local/anaconda3/envs/convdif/lib/python3.9/site-packages/wandb/apis/normalize.py:26, in normalize_exceptions.<locals>.wrapper(*args, **kwargs)
#      25 try:
# ---> 26     return func(*args, **kwargs)
#      27 except requests.HTTPError as err:
#
# File /usr/local/anaconda3/envs/convdif/lib/python3.9/site-packages/wandb/apis/public.py:867, in Api.run(self, path)
#     866 if not self._runs.get(path):
# --> 867     self._runs[path] = Run(self.client, entity, project, run_id)
#     868 return self._runs[path]
#
# File /usr/local/anaconda3/envs/convdif/lib/python3.9/site-packages/wandb/apis/public.py:1699, in Run.__init__(self, client, entity, project, run_id, attrs, include_sweeps)
#    1697 self._state = _attrs.get("state", "not found")
# -> 1699 self.load(force=not _attrs)
#
# File /usr/local/anaconda3/envs/convdif/lib/python3.9/site-packages/wandb/apis/public.py:1803, in Run.load(self, force)
#    1798 if (
#    1799     response is None
#    1800     or response.get("project") is None
#    1801     or response["project"].get("run") is None
#    1802 ):
# -> 1803     raise ValueError("Could not find run %s" % self)
#    1804 self._attrs = response["project"]["run"]
#
# ValueError: Could not find run <Run salv47/ConvexDiffusion/3kkx899f (not found)>
#
# During handling of the above exception, another exception occurred:
#
# CommError                                 Traceback (most recent call last)
# Cell In [6], line 1
# ----> 1 results = reload_and_plot_preds(wandb_id, ar_steps=8)
#       2 results_mlp = reload_and_plot_preds('8319ujtg', ar_steps=8)
#
# Cell In [4], line 2, in reload_and_plot_preds(wandb_id, ar_steps)
#       1 def reload_and_plot_preds(wandb_id: str, ar_steps=0):
# ----> 2     reloaded = reload_checkpoint_from_wandb(wandb_id, override_key_value=[f'datamodule.data_dir={str(data_dir)}'])
#       3     model = reloaded['model']
#       4     datamodule = reloaded['datamodule']
#
# File ~/repos/convex-diffusion/src/utilities/wandb_api.py:147, in reload_checkpoint_from_wandb(run_id, entity, project, epoch, override_key_value, local_checkpoint_path)
#     145 from src.interface import reload_model_from_config_and_ckpt
#     146 run_path = f"{entity}/{project}/{run_id}"
# --> 147 config = load_hydra_config_from_wandb(run_path, override_key_value=override_key_value)
#     149 if local_checkpoint_path is not None:
#     150     best_model_fname = best_model_path = local_checkpoint_path
#
# File ~/repos/convex-diffusion/src/utilities/wandb_api.py:88, in load_hydra_config_from_wandb(run_path, base_config, override_config, override_key_value)
#      74 def load_hydra_config_from_wandb(
#      75         run_path: str,
#      76         base_config: Optional[DictConfig] = None,
#      77         override_config: Optional[DictConfig] = None,
#      78         override_key_value: List[str] = None,
#      79 ) -> DictConfig:
#      80     """
#      81     Args:
#      82         run_path (str): the wandb ENTITY/PROJECT/ID (e.g. ID=2r0l33yc) corresponding to the config to-be-reloaded
#    (...)
#      86         override_key_value: each element is expected to have a "=" in it, like datamodule.num_workers=8
#      87     """
# ---> 88     run = wandb.Api(timeout=77).run(run_path)
#      89     override_key_value = override_key_value or []
#      90     if not isinstance(override_key_value, list):
#
# File /usr/local/anaconda3/envs/convdif/lib/python3.9/site-packages/wandb/apis/normalize.py:62, in normalize_exceptions.<locals>.wrapper(*args, **kwargs)
#      60     raise
#      61 else:
# ---> 62     raise CommError(message, err).with_traceback(sys.exc_info()[2])
#
# File /usr/local/anaconda3/envs/convdif/lib/python3.9/site-packages/wandb/apis/normalize.py:26, in normalize_exceptions.<locals>.wrapper(*args, **kwargs)
#      24 message = "Whoa, you found a bug."
#      25 try:
# ---> 26     return func(*args, **kwargs)
#      27 except requests.HTTPError as err:
#      28     raise CommError(err.response, err)
#
# File /usr/local/anaconda3/envs/convdif/lib/python3.9/site-packages/wandb/apis/public.py:867, in Api.run(self, path)
#     865 entity, project, run_id = self._parse_path(path)
#     866 if not self._runs.get(path):
# --> 867     self._runs[path] = Run(self.client, entity, project, run_id)
#     868 return self._runs[path]
#
# File /usr/local/anaconda3/envs/convdif/lib/python3.9/site-packages/wandb/apis/public.py:1699, in Run.__init__(self, client, entity, project, run_id, attrs, include_sweeps)
#    1696 self._summary = None
#    1697 self._state = _attrs.get("state", "not found")
# -> 1699 self.load(force=not _attrs)
#
# File /usr/local/anaconda3/envs/convdif/lib/python3.9/site-packages/wandb/apis/public.py:1803, in Run.load(self, force)
#    1797 response = self._exec(query)
#    1798 if (
#    1799     response is None
#    1800     or response.get("project") is None
#    1801     or response["project"].get("run") is None
#    1802 ):
# -> 1803     raise ValueError("Could not find run %s" % self)
#    1804 self._attrs = response["project"]["run"]
#    1805 self._state = self._attrs["state"]
#
# CommError: Could not find run <Run salv47/ConvexDiffusion/3kkx899f (not found)>

# %%
def plot_results(results, ar_step=0):
    fig, ax = plt.subplots(4, 4, figsize=(10, 10))
    col = 0
    tsize=results['preds'].shape[0]
    for i in range(8):
        k =  tsize// (i+1) - 1
        p = results['preds'][k, 0, ...]
        y = results['targets'][k, 0, ...]

        ax[i%4, col].imshow(p)
        ax[i%4, col+1].imshow(y)
        if i % 4 == 3:
            col+=2
    for a in ax.flat:
        a.set_xticklabels([])
        a.set_yticklabels([])
        
def plot_ar(results, ar_steps=5, show_targets=True):
    k=3
    nrows = 2 if show_targets else 1
    fig, axs = plt.subplots(nrows, ar_steps, figsize=(ar_steps*k, nrows*k), sharey=True, sharex=True)
    for i in range(ar_steps):
        pred_key = 'preds' if i == 0  else f'preds_ar_{i}'
        p = results[pred_key][0, 0, ...]
        y = results['targets'][i, 0, ...]
        if show_targets:
            axs[0, i].imshow(p)
            axs[1, i].imshow(y)
        else:
            axs[i].imshow(p)

# %%
plot_ar(results_mlp, ar_steps=8, show_targets=False)
plot_ar(results, ar_steps=8)

# %%
#plt.rcParams['figure.figsize'] = [40, 15]  # general matplotlib parameters
plt.rcParams['figure.dpi'] = 60 
plot_results(results)
plot_results(results_mlp)

# %%
def plot_results(results, ar_step=0):
    fig, ax = plt.subplots(4, 4, figsize=(10, 10))
    col = 0
    tsize=results['preds'].shape[0]
    for i in range(8):
        k =  tsize// (i+1) - 1
        p = results['preds'][k, 0, ...]
        y = results['targets'][k, 0, ...]

        ax[i%4, col].imshow(p)
        ax[i%4, col+1].imshow(y)
        if i % 4 == 3:
            col+=2
    for a in ax.flat:
        a.set_xticklabels([])
        a.set_yticklabels([])
        
def plot_ar(results, ar_steps=5, show_targets=True):
    k=3
    nrows = 2 if show_targets else 1
    fig, axs = plt.subplots(nrows, ar_steps, figsize=(ar_steps*k, nrows*k), sharey=True, sharex=True)
    for i in range(ar_steps):
        pred_key = 'preds' if i == 0  else f'preds_ar_{i}'
        p = results[pred_key][0, 0, ...]
        y = results['targets'][i, 0, ...]
        if show_targets:
            axs[0, i].imshow(p)
            axs[1, i].imshow(y)
        else:
            axs[i].imshow(p)

# %%
plot_ar(results_mlp, ar_steps=8, show_targets=False)
plot_ar(results, ar_steps=8)

# %%
#plt.rcParams['figure.figsize'] = [40, 15]  # general matplotlib parameters
plt.rcParams['figure.dpi'] = 60 
plot_results(results)
plot_results(results_mlp)
